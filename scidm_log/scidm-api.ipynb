# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
apidata = pd.read_csv('/log/api/api.log', header=None, names = ['ip', 'time', 'api', 'para', 'requests'])
apidata
# Out:
#                                          ip                        time  \
# 220.244.207.158  16/Sep/2019:10:14:48 +0800              package_search
# 140.110.240.52   16/Sep/2019:20:32:16 +0800                package_show
# 140.110.240.52   16/Sep/2019:20:32:17 +0800            resource_create
# 140.110.35.130   07/Sep/2019:16:21:32 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:21:45 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:22:31 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:23:29 +0800               package_list
# 140.110.35.130   07/Sep/2019:16:23:55 +0800               package_list
# 140.110.35.130   07/Sep/2019:16:24:31 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:25:03 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:25:30 +0800                package_show
# 140.110.35.130   07/Sep/2019:16:26:36 +0800                package_show
# ...

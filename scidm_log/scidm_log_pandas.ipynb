# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# from ipwhois import IPWhois

# %%
data = pd.read_csv('/Users/fish/Downloads/dataset.csv', header=None, names=['ip', 'dataset','download', 'date', 'size', 'request', 'user-agent'])
data.head()
# Out:
#               ip                               dataset  download  \
# 0   66.249.71.10                                 False     False
# 1   66.249.71.10                                 False     False
# 2   66.249.71.11  5b25852a-9d96-4d6d-a7b6-a45bb3148296     False
# 3  40.77.167.163  60e0a685-9454-44e7-83e5-09a87264f04e     False
# 4    66.249.71.9                                 False     False
#
#                          date  size  \
# 0  20/Jun/2019:06:25:23 +0800   806
# 1  20/Jun/2019:06:25:23 +0800   564
# 2  20/Jun/2019:06:25:26 +0800  6464
# 3  20/Jun/2019:06:30:51 +0800  7686
# 4  20/Jun/2019:06:32:53 +0800   806
#
#                                              request  \
# 0                           GET /robots.txt HTTP/1.0
# 1             GET /rating/dataset/frg0606/1 HTTP/1.0
# 2                      GET /dataset/frg0606 HTTP/1.0
# 3  GET /dataset/nih-clinical-center-deeplesion/re...
# 4                           GET /robots.txt HTTP/1.0
#
#                                           user-agent
# 0  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# 1  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 2  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# 3  Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# 4  Mozilla/5.0 (compatible; Googlebot/2.1; +http:...

# %%
data2 = pd.read_csv('/Users/fish/Downloads/dataset-group.csv', header=None, names=['ip', 'dataset','download', 'date', 'size', 'request', 'user-agent'])
data2.head()
# Out:
#                      ip                               dataset  download  \
# research  40.77.167.163  60e0a685-9454-44e7-83e5-09a87264f04e     False
# research    5.45.207.63  0272e4d2-09d5-45e8-bbf0-c318fab67308     False
# research   66.102.8.136  c4b42f2d-ef31-4a13-b65a-75896396eb5c     False
# research   66.102.8.136  c4b42f2d-ef31-4a13-b65a-75896396eb5c      True
# research   179.6.201.94  c4b42f2d-ef31-4a13-b65a-75896396eb5c     False
#
#                                 date  size  \
# research  20/Jun/2019:06:30:51 +0800  7686
# research  20/Jun/2019:06:52:04 +0800  9014
# research  20/Jun/2019:07:52:02 +0800  5359
# research  20/Jun/2019:07:52:06 +0800  1736
# research  20/Jun/2019:07:52:13 +0800   241
#
#                                                     request  \
# research  GET /dataset/nih-clinical-center-deeplesion/re...
# research                  GET /dataset/open-images HTTP/1.0
# research  GET /dataset/cargo-2000-freight-tracking-and-t...
# research  GET /dataset/cargo-2000-freight-tracking-and-t...
# research  OPTIONS /dataset/c4b42f2d-ef31-4a13-b65a-75896...
#
#                                                  user-agent
# research  Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# research  Mozilla/5.0 (compatible; YandexBot/3.0; +http:...
# research  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# research  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# research  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...

# %%
data3 = pd.read_csv('/Users/fish/Downloads/dataset-organization.csv', header=None, names=['ip', 'dataset','download', 'date', 'size', 'request', 'user-agent'])
data3.head()
# Out:
#                      ip                               dataset  download  \
# False      66.249.71.10                                 False     False
# False      66.249.71.10                                 False     False
# kcg-data   66.249.71.11  5b25852a-9d96-4d6d-a7b6-a45bb3148296     False
# aidm      40.77.167.163  60e0a685-9454-44e7-83e5-09a87264f04e     False
# False       66.249.71.9                                 False     False
#
#                                 date  size  \
# False     20/Jun/2019:06:25:23 +0800   806
# False     20/Jun/2019:06:25:23 +0800   564
# kcg-data  20/Jun/2019:06:25:26 +0800  6464
# aidm      20/Jun/2019:06:30:51 +0800  7686
# False     20/Jun/2019:06:32:53 +0800   806
#
#                                                     request  \
# False                              GET /robots.txt HTTP/1.0
# False                GET /rating/dataset/frg0606/1 HTTP/1.0
# kcg-data                      GET /dataset/frg0606 HTTP/1.0
# aidm      GET /dataset/nih-clinical-center-deeplesion/re...
# False                              GET /robots.txt HTTP/1.0
#
#                                                  user-agent
# False     Mozilla/5.0 (compatible; Googlebot/2.1; +http:...
# False     Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# kcg-data  Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5X Bu...
# aidm      Mozilla/5.0 (compatible; bingbot/2.0; +http://...
# False     Mozilla/5.0 (compatible; Googlebot/2.1; +http:...

# %% [markdown]
# # 前十大 IP

# %%
ip_count = pd.DataFrame({'count' : data.groupby(['ip']).size()}).reset_index().sort_values('count', ascending=False).head(100)

save_source = []
for IP in ip_count['ip']:
    try:
        obj = IPWhois(IP.strip())

    except Exception as e:
        obj = 'error'
        
    while True:
        try:
            results = obj.lookup_rdap(depth=1)
        except Exception as e:
            if 'HTTP lookup failed' in str(e):
                results['asn_country_code'] = 'error'
                source = str(e)
                break
            else:
                continue
        break

#     # 判斷 ip 來源
    if results['asn_country_code'] == 'error':
        save_source.append(source)
    elif results['asn_country_code'] == 'TW':
        if 'TANET' in results['network']['name']:
            source = '學術單位'
            save_source.append(source)
        elif results['network']['name'] == 'GSN-NET':
            source = '政府機關'
            save_source.append(source)
        else:
            source = '企業民眾'
            save_source.append(source)
    elif results['asn_country_code'] != 'TW':
        source = '海外民眾'
        save_source.append(source)

print(len(save_source))
ip_count['source'] = save_source

ip_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-85129c2ae027> in <module>
#      12         try:
# ---> 13             results = obj.lookup_rdap(depth=1)
#      14         except Exception as e:
#
# AttributeError: 'str' object has no attribute 'lookup_rdap'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-85129c2ae027> in <module>
#      18                 break
#      19             else:
# ---> 20                 continue
#      21         break
#      22
#
# KeyboardInterrupt:

# %%
plt.pie(ip_count['count'], labels = ip_count['ip'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 有下載動作的 IP

# %%
for_ip_dataframe = data[data['download'] == True]
for_ip_dataframe.head()
# Out:
#                  ip                               dataset  download  \
# 132   66.249.79.236  21bdade4-f5e1-46ca-a969-2c8c8e5cd71c      True
# 148   66.249.71.139  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1      True
# 155   66.249.71.139  fe1649d3-9710-4133-9366-a1acc2722c76      True
# 164   66.249.71.139  f498e5df-e08c-4b7f-a977-d4fa6920e004      True
# 1135  66.249.71.141  81ac615f-efb0-4717-ae2a-19fddf3da4dd      True
#
#                             date  size  \
# 132   17/Oct/2018:06:25:58 +0800  2696
# 148   17/Oct/2018:06:26:05 +0800  1546
# 155   17/Oct/2018:06:26:11 +0800  2178
# 164   17/Oct/2018:06:26:12 +0800  2693
# 1135  17/Oct/2018:06:35:47 +0800  2561
#
#                                                 request
# 132   GET /dataset/insight_classifiction_dataset_7_1...
# 148   GET /dataset/lass-2018q3/resource/493cea3d-e9c...
# 155   GET /dataset/376570000a-000039/resource/817044...
# 164   GET /dataset/insight_classifiction_dataset_7_1...
# 1135  GET /dataset/insight_classifiction_dataset_7_1...

# %%
ip_count2 = pd.DataFrame({'count' : for_ip_dataframe.groupby(['ip']).size()}).reset_index().sort_values('count', ascending=False).head(10)
ip_count2
# Out:
#                 ip  count
# 770  66.249.71.139   2489
# 769   66.249.71.13   2196
# 680  52.23.222.220   1391
# 567    34.224.2.58   1277
# 809  66.249.79.236    894
# 771   66.249.71.14    825
# 795   66.249.71.77    791
# 821   66.249.79.50    574
# 827   66.249.79.77    477
# 777   66.249.71.15    458

# %%
plt.pie(ip_count2['count'], labels = ip_count2['ip'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 前十大資料集

# %%
datasetdata = data[~data['dataset'].isin(['False'])]
dataset_count = pd.DataFrame({'count' : datasetdata.groupby(['dataset']).size()}).reset_index().sort_values('count', ascending=False).head(10)
dataset_count
# Out:
#                                    dataset  count
# 13    0080258d-3658-47ee-b2cf-cba8b2f6e72e   7040
# 3909  78bb96a8-d88c-4d04-8d82-407f4510dc07   2407
# 4122  7f7a049e-a512-420b-a989-f2112e800a25   2397
# 3963  7a23dd3e-642c-4a0e-8cb9-3793ff64948b   2333
# 6582  cc806774-cec6-47ae-8f69-069832a81033   1897
# 7517  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1   1688
# 4272  8406285b-e878-4033-98ea-ad5aa58db9af   1536
# 7928  f48a6e9f-607a-45f6-a446-d9fe5e1ba9b5   1517
# 4732  92699b39-0825-4801-8426-5ee00cede691   1454
# 5857  b5563771-bd75-4d63-81ba-12945e40c4db   1452

# %%
plt.pie(dataset_count['count'], labels = dataset_count['dataset'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 有被下載的資料集

# %%
dataset_count2 = pd.DataFrame({'count' : for_ip_dataframe.groupby(['dataset']).size()}).reset_index().sort_values('count', ascending=False).head(10)
dataset_count2
# Out:
#                                    dataset  count
# 863                                  False   1329
# 1211  da1ff08e-2a2e-4acb-9e8c-09649ceaf1fc    676
# 797   94312a47-b17c-4a1b-b971-d1815df986fb    553
# 10    0272e4d2-09d5-45e8-bbf0-c318fab67308    469
# 1270  e32bd551-b3ff-4043-bf39-5eaa6fb2f40c    450
# 693   8406285b-e878-4033-98ea-ad5aa58db9af    410
# 637   7a23dd3e-642c-4a0e-8cb9-3793ff64948b    408
# 788   92699b39-0825-4801-8426-5ee00cede691    405
# 979   b5563771-bd75-4d63-81ba-12945e40c4db    397
# 686   81ac615f-efb0-4717-ae2a-19fddf3da4dd    371

# %%
plt.pie(dataset_count2['count'], labels = dataset_count2['dataset'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 前十大 group

# %%
groupdata = pd.read_csv('dataset-group.csv', header=None)
groupdata.head()
# Out:
#                    0              1                                     2  \
# 0  publicinformation  66.249.71.139  a8b7d7e7-f559-4281-8885-1723bcdb0f98
# 1            traffic  66.249.79.238  42ecd9c7-6dd0-4c77-9de7-3b2391dd50ae
# 2  publicinformation  66.249.71.139  fe1649d3-9710-4133-9366-a1acc2722c76
# 3        environment  66.249.79.236  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
# 4               life  66.249.79.236  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
#
#        3                           4      5  \
# 0  False  17/Oct/2018:06:25:41 +0800   4188
# 1  False  17/Oct/2018:06:25:44 +0800   4278
# 2  False  17/Oct/2018:06:25:54 +0800   5489
# 3  False  17/Oct/2018:06:25:56 +0800  11429
# 4  False  17/Oct/2018:06:25:56 +0800  11429
#
#                                                    6
# 0  GET /dataset/a09000000e-000240/resource/514870...
# 1  GET /dataset/379730000a-001433/resource/469aa7...
# 2  GET /dataset/376570000a-000039/resource/817044...
# 3  GET /dataset/lass-2018q3/resource/493cea3d-e9c...
# 4  GET /dataset/lass-2018q3/resource/493cea3d-e9c...

# %%
groupdata = pd.read_csv('dataset-group.csv', header=None, names=['group', 'ip', 'dataset','download', 'date', 'size', 'request'])
groupdata.head()
# Out:
#                group             ip                               dataset  \
# 0  publicinformation  66.249.71.139  a8b7d7e7-f559-4281-8885-1723bcdb0f98
# 1            traffic  66.249.79.238  42ecd9c7-6dd0-4c77-9de7-3b2391dd50ae
# 2  publicinformation  66.249.71.139  fe1649d3-9710-4133-9366-a1acc2722c76
# 3        environment  66.249.79.236  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
# 4               life  66.249.79.236  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
#
#    download                        date   size  \
# 0     False  17/Oct/2018:06:25:41 +0800   4188
# 1     False  17/Oct/2018:06:25:44 +0800   4278
# 2     False  17/Oct/2018:06:25:54 +0800   5489
# 3     False  17/Oct/2018:06:25:56 +0800  11429
# 4     False  17/Oct/2018:06:25:56 +0800  11429
#
#                                              request
# 0  GET /dataset/a09000000e-000240/resource/514870...
# 1  GET /dataset/379730000a-001433/resource/469aa7...
# 2  GET /dataset/376570000a-000039/resource/817044...
# 3  GET /dataset/lass-2018q3/resource/493cea3d-e9c...
# 4  GET /dataset/lass-2018q3/resource/493cea3d-e9c...

# %%
groupdata['date'] = pd.to_datetime(groupdata['date'], format= '%d/%b/%Y:%H:%M:%S +0800', utc=True)

# %%
groupdata.sort_values('date', inplace=True)
groupdata
# Out:
#                    group               ip  \
# 51210           research   61.244.168.162
# 51211           research   61.244.168.162
# 51212           research   61.244.168.162
# 51213  publicinformation    211.21.93.157
# 51214  publicinformation    211.21.93.157
# 51208           research     37.9.113.191
# 51209           research     42.76.238.28
# 51203           research     61.231.2.107
# 51204           research     207.46.13.13
# 51205           research  118.163.255.186
# 51206           research  118.163.255.186
# 51207           research  118.163.255.186
# 51189           research  118.163.255.186
# 51190           research  118.163.255.186
# 51191           research  118.163.255.186
# 51192           research  118.163.255.186
# 51193           research  118.163.255.186
# 51194           research  118.163.255.186
# 51195           research   140.96.113.187
# 51196  publicinformation    211.21.93.157
# 51198               life    211.21.93.157
# 51197        environment    211.21.93.157
# 51199           research     140.92.47.69
# 51200           research     140.92.47.69
# 51201           research  118.163.255.186
# 51202           research   140.110.59.216
# 51177  publicinformation   163.17.133.140
# 51178  publicinformation   163.17.133.140
# 51179  publicinformation   163.17.133.140
# 51180  publicinformation   163.17.133.140
# ...                  ...              ...
# 386             research    140.110.35.75
# 387                 life    66.249.71.139
# 388              traffic    66.249.71.139
# 389    publicinformation    66.249.71.139
# 390             research    66.249.71.139
# 391    publicinformation    66.249.71.139
# 392    publicinformation   163.20.242.146
# 393    publicinformation   163.20.242.146
# 394    publicinformation   163.20.242.146
# 395    publicinformation   163.20.242.146
# 396    publicinformation   163.20.242.146
# 397              traffic    66.249.79.236
# 398    publicinformation    66.249.71.139
# 399    publicinformation    66.249.71.139
# 401    publicinformation    66.249.71.141
# 400              traffic    66.249.71.141
# 402    publicinformation    66.249.71.139
# 403    publicinformation    140.116.1.141
# 404    publicinformation    140.116.1.141
# 405    publicinformation    66.249.79.240
# 406    publicinformation    66.249.71.141
# 407    publicinformation    66.249.71.141
# 408              traffic    66.249.71.139
# 410                 life    66.249.71.141
# 409          environment    66.249.71.141
# 412    publicinformation    66.249.79.236
# 411              traffic    66.249.79.236
# 414                 life    66.249.71.143
# 413          environment    66.249.71.143
# 415                 life    66.249.71.139
#
# 401   2018-10-17 14:27:14+00:00      2225
# 400   2018-10-17 14:27:15+00:00      4186
# 402   2018-10-17 14:27:28+00:00      4245
# 403   2018-10-17 14:29:10+00:00      5316
# 404   2018-10-17 14:29:14+00:00      5316
# 405   2018-10-17 14:32:27+00:00      4328
# 406   2018-10-17 14:37:13+00:00      5203
# 407   2018-10-17 14:37:22+00:00      5470
# 408   2018-10-17 14:37:23+00:00      4493
# 410   2018-10-17 14:49:12+00:00     10337
# 409   2018-10-17 14:49:12+00:00     10337
# 412   2018-10-17 14:49:20+00:00      5272
# 411   2018-10-17 14:49:20+00:00      5272
# 414   2018-10-17 14:57:29+00:00     10529
# 413   2018-10-17 14:57:29+00:00     10529
# 415   2018-10-17 14:57:38+00:00      4934
#
#                                                  request
# 51210                GET /dataset/20-newsgroups HTTP/1.0
# 51211  GET /dataset/20-newsgroups/resource/75613c4c-b...
# 51212  GET /dataset/9760dec7-308e-41c5-950f-517e9439c...
# 51213            GET /dataset/a27000000g-000213 HTTP/1.0
# 51214  GET /dataset/a27000000g-000213/resource/069ff5...
# 51208                        GET /dataset/mnist HTTP/1.0
# 51209                    GET /dataset/eland-001 HTTP/1.0
# 51203                        GET /dataset/mnist HTTP/1.0
# 51204                        GET /dataset/mnist HTTP/1.0
# 51205  GET /dataset/dc139aae-2f6d-432b-a221-a095683c4...
# 51206          GET /dataset/imagenet-ilsvrc2012 HTTP/1.0
# 51207  GET /dataset/a0f015b3-faae-43df-8d8e-3ce935f8f...
# 51189  GET /dataset/cifar-100/resource/fc9d065f-acfc-...
# 51190  GET /dataset/cifar-100/resource/99c721ae-fe0f-...
# 51191  GET /dataset/cifar-100/resource/167ec504-cf30-...
# 51192  GET /dataset/darpa-timit/resource/fc226e6f-696...
# 51193  GET /dataset/20-newsgroups/resource/9a445163-8...
# 51194  GET /dataset/20-newsgroups/resource/5931fc47-0...
# 51195                        GET /dataset/mnist HTTP/1.0
# 51196            GET /dataset/a27000000g-000213 HTTP/1.0
# 51198  GET /dataset/4ba06157-3854-4111-9383-3b8a188c9...
# 51197  GET /dataset/4ba06157-3854-4111-9383-3b8a188c9...
# 51199                        GET /dataset/mnist HTTP/1.0
# 51200                   GET /dataset/caltech256 HTTP/1.0
# 51201  GET /dataset/20-newsgroups/resource/75613c4c-b...
# 51202           GET /dataset/most-acad-tutorial HTTP/1.0
# 51177            GET /dataset/a09000000e-000185 HTTP/1.0
# 51178  GET /dataset/a09000000e-000185/resource/368cb9...
# 51179            GET /dataset/313200000g-000147 HTTP/1.0
# 51180  GET /dataset/313200000g-000147/resource/610774...
# ...                                                  ...
# 386                  GET /dataset/tensorflow-ai HTTP/1.0
# 387              GET /dataset/355000000i-000612 HTTP/1.0
# 388    GET /dataset/315260000m-000054/resource/241c03...
# 389    GET /dataset/313020000g-000015/resource/122f10...
# 390    GET /dataset/movie/resource/679c62c2-b286-4104...
# 391              GET /dataset/a07040000d-000013 HTTP/1.0
# 392    GET /dataset/a09000000e-000396/resource/58e1da...
# 393    GET /dataset/a09000000e-000396/resource/58e1da...
# 394    GET /dataset/a09000000e-000396/resource/58e1da...
# 395    GET /dataset/a09000000e-000396/resource/58e1da...
# 396    GET /dataset/a09000000e-000396/resource/58e1da...
# 397              GET /dataset/387130300c-004571 HTTP/1.0
# 398    GET /dataset/376580000a-921554/resource/58ee52...
# 399              GET /dataset/382000000a-002052 HTTP/1.0
# 401    GET /dataset/376580000a-921554/resource/58ee52...
# 400    GET /dataset/369000000h-000080/resource/ba1d9c...
# 402    GET /dataset/a09010000e-000002/resource/bc9ca9...
# 403              GET /dataset/a41000000g-000205 HTTP/1.0
# 404              GET /dataset/a41000000g-000205 HTTP/1.0
# 405    GET /dataset/a21000000i-000134/resource/08c337...
# 406              GET /dataset/a17000000j-020106 HTTP/1.0
# 407    GET /dataset/a09000000e-000010/resource/8fce7f...
# 408    GET /dataset/315260000m-000054/resource/c87189...
# 410    GET /dataset/lass-before-2017/resource/7011dc0...
# 409    GET /dataset/lass-before-2017/resource/7011dc0...
# 412    GET /dataset/https-scidm-nchc-org-tw-dataset-n...
# 411    GET /dataset/https-scidm-nchc-org-tw-dataset-n...
# 414    GET /dataset/lass-2018q3/resource/e2cc8d47-3db...
# 413    GET /dataset/lass-2018q3/resource/e2cc8d47-3db...
# 415              GET /dataset/397000000a-002264 HTTP/1.0
#
# [107581 rows x 7 columns]

# %%
groupdata = pd.read_csv('dataset-group.csv', header=None)
groupdata = groupdata.drop([4], axis = 1)
groupdata = groupdata.rename(index=str, columns={0:'group', 1:'ip', 2:'dataset', 3:'download'})
group_count = pd.DataFrame({'count' : groupdata.groupby(['group']).size()}).reset_index().sort_values('count', ascending=False).head(10)
group_count
# Out:
#                   group  count
# 6     publicinformation  35819
# 4                  life  30161
# 7              research  17055
# 2           environment  15134
# 8               traffic   5001
# 1                 ai-ml   1945
# 5               medical   1900
# 3  information-security    535
# 0             afasi_gov     20
# 9                 voice     11

# %%
plt.pie(group_count['count'], labels = group_count['group'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 有被 Download 的前十大 group

# %%
download_group_data = groupdata[groupdata['download'] == True]
download_group_data.head()
# Out:
#                 group             ip                               dataset  \
# 7         environment  66.249.71.139  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
# 8                life  66.249.71.139  e8c17e69-fb72-4fa0-92bf-03bf5e8959c1
# 9   publicinformation  66.249.71.139  fe1649d3-9710-4133-9366-a1acc2722c76
# 18  publicinformation  66.249.79.236  29850a9c-534c-4bc6-be01-ace2d9c5cea0
# 34        environment  66.249.79.236  92699b39-0825-4801-8426-5ee00cede691
#
#     download                        date  size  \
# 7       True  17/Oct/2018:06:26:05 +0800  1546
# 8       True  17/Oct/2018:06:26:05 +0800  1546
# 9       True  17/Oct/2018:06:26:11 +0800  2178
# 18      True  17/Oct/2018:06:46:03 +0800  2189
# 34      True  17/Oct/2018:07:16:43 +0800  1632
#
#                                               request
# 7   GET /dataset/lass-2018q3/resource/493cea3d-e9c...
# 8   GET /dataset/lass-2018q3/resource/493cea3d-e9c...
# 9   GET /dataset/376570000a-000039/resource/817044...
# 18  GET /dataset/a09000000e-000105/resource/0cfb4a...
# 34  GET /dataset/lass-2017q2/resource/8d74d9df-f64...

# %%
download_group_data
# Out:
#                        group               ip  \
# 7                environment    66.249.71.139
# 8                       life    66.249.71.139
# 9          publicinformation    66.249.71.139
# 18         publicinformation    66.249.79.236
# 34               environment    66.249.79.236
# 116     GET /dataset/ctsp_sewage/resource/65f49c64-c3b...
# 119     GET /dataset/18778e3d-44fb-4efc-bcdf-8e48c1fdc...
# 120     GET /dataset/18778e3d-44fb-4efc-bcdf-8e48c1fdc...
# 123     GET /dataset/open-images/resource/687c6d10-ea5...
# 134     GET /dataset/https-scidm-nchc-org-tw-dataset-n...
# 135     GET /dataset/https-scidm-nchc-org-tw-dataset-n...
# 160     GET /dataset/dataset-for-sensorless-drive-diag...
# 161     GET /dataset/52939715-69a1-42c1-974c-d7150dd5c...
# 167     GET /dataset/a09000000e-000526/resource/2badda...
# 174     GET /dataset/376560000a-1496918728/resource/88...
# 176     GET /dataset/honeynet-md5/resource/c034cea4-d9...
# ...                                                   ...
# 107134  GET /dataset/315070000h-700014/resource/ce4149...
# 107146  GET /dataset/315070700h-000014/resource/3f79ac...
# 107153  GET /dataset/355000000i-000071/resource/8f372c...
# 107155  GET /dataset/355000000i-000071/resource/8f372c...
# 107221  GET /dataset/c79b5886-cda1-4154-ba06-5d7f22312...
# 107222  GET /dataset/c79b5886-cda1-4154-ba06-5d7f22312...
# 107229  GET /dataset/most_science-parks_water_consumpt...
# 107230  GET /dataset/most_science-parks_water_consumpt...
# 107233  GET /dataset/most_science-parks_water_consumpt...
# 107234  GET /dataset/most_science-parks_water_consumpt...
# 107235  GET /dataset/6b38221c-545e-4a7b-8d03-88917cfec...
# 107236  GET /dataset/6b38221c-545e-4a7b-8d03-88917cfec...
# 107242  GET /dataset/cgdr/resource/bc237859-4f2e-4cba-...
# 107244  GET /dataset/cgdr/resource/bc237859-4f2e-4cba-...
# 107245  GET /dataset/b9c3603a-78ca-4c7e-8e5a-4abf658c3...
# 107247  GET /dataset/cgdr/resource/bc237859-4f2e-4cba-...
# 107248  GET /dataset/b9c3603a-78ca-4c7e-8e5a-4abf658c3...
# 107251  GET /dataset/36e757c6-6874-4a40-a5fd-0353cefa4...
# 107281  GET /dataset/http-www-post-gov-tw-post-interne...
# 107282  GET /dataset/http-www-post-gov-tw-post-interne...
# 107293  GET /dataset/most_science-parks_sewage-treatme...
# 107294  GET /dataset/most_science-parks_sewage-treatme...
# 107295  GET /dataset/a999ebc8-3230-49eb-ac55-8df1b2aae...
# 107296  GET /dataset/a999ebc8-3230-49eb-ac55-8df1b2aae...
# 107499  GET /dataset/scidm-nchc-org-tw-dataset-qacct20...
# 107500  GET /dataset/scidm-nchc-org-tw-dataset-qacct20...
# 107559  GET /dataset/5e7b7ef7-9d21-4224-8ea5-b1822be3a...
# 107560  GET /dataset/5e7b7ef7-9d21-4224-8ea5-b1822be3a...
# 107567  GET /dataset/5e7b7ef7-9d21-4224-8ea5-b1822be3a...
# 107568  GET /dataset/5e7b7ef7-9d21-4224-8ea5-b1822be3a...
#
# [12975 rows x 7 columns]

# %%
group_count2 = pd.DataFrame({'count' : download_group_data.groupby(['group']).size()}).reset_index().sort_values('count', ascending=False).head(10)
group_count2
# Out:
#                   group  count
# 4                  life   3780
# 2           environment   3123
# 7              research   3052
# 6     publicinformation   1898
# 8               traffic    540
# 1                 ai-ml    256
# 3  information-security    229
# 5               medical     94
# 9                 voice      2
# 0             afasi_gov      1

# %%
plt.pie(group_count2['count'], labels = group_count2['group'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # 前十大組織

# %%
organization_data = pd.read_csv('dataset-organization.csv', header=None)
organization_data.head()
# Out:
#        0                1      2      3                           4    5  \
# 0  False  140.110.141.141  False  False  17/Oct/2018:06:25:10 +0800  424
# 1  False  140.110.141.141  False  False  17/Oct/2018:06:25:13 +0800  424
# 2  False  140.110.141.141  False  False  17/Oct/2018:06:25:13 +0800  424
# 3  False  140.110.141.141  False  False  17/Oct/2018:06:25:13 +0800  424
# 4  False  140.110.141.141  False  False  17/Oct/2018:06:25:13 +0800  424
#
#                                           6
# 0  POST /api/action/package_create HTTP/1.0
# 1  POST /api/action/package_create HTTP/1.0
# 2  POST /api/action/package_create HTTP/1.0
# 3  POST /api/action/package_create HTTP/1.0
# 4  POST /api/action/package_create HTTP/1.0

# %%
organization_data = pd.read_csv('dataset-organization.csv', header=None, names = ['org', 'ip', 'dataset', 'download', 'date', 'size', 'requests'])
organization_data.head()
# Out:
#      org               ip dataset  download                        date  size  \
# 0  False  140.110.141.141   False     False  17/Oct/2018:06:25:10 +0800   424
# 1  False  140.110.141.141   False     False  17/Oct/2018:06:25:13 +0800   424
# 2  False  140.110.141.141   False     False  17/Oct/2018:06:25:13 +0800   424
# 3  False  140.110.141.141   False     False  17/Oct/2018:06:25:13 +0800   424
# 4  False  140.110.141.141   False     False  17/Oct/2018:06:25:13 +0800   424
#
#                                    requests
# 0  POST /api/action/package_create HTTP/1.0
# 1  POST /api/action/package_create HTTP/1.0
# 2  POST /api/action/package_create HTTP/1.0
# 3  POST /api/action/package_create HTTP/1.0
# 4  POST /api/action/package_create HTTP/1.0

# %%
organization_data = organization_data[organization_data['org'] != 'False']
organization_data.head()
# Out:
#                  org             ip                               dataset  \
# 59        ipgod-nchc  66.249.71.143  7f7a049e-a512-420b-a989-f2112e800a25
# 97        ipgod-nchc  66.249.71.139  a8b7d7e7-f559-4281-8885-1723bcdb0f98
# 104       ipgod-nchc  66.249.79.238  42ecd9c7-6dd0-4c77-9de7-3b2391dd50ae
# 107  nchc-clean-data  66.249.71.139  21bdade4-f5e1-46ca-a969-2c8c8e5cd71c
# 113  nchc-clean-data  66.249.79.236  21bdade4-f5e1-46ca-a969-2c8c8e5cd71c
#
#      download                        date   size  \
# 59      False  17/Oct/2018:06:25:21 +0800  12251
# 97      False  17/Oct/2018:06:25:41 +0800   4188
# 104     False  17/Oct/2018:06:25:44 +0800   4278
# 107     False  17/Oct/2018:06:25:46 +0800  11403
# 113     False  17/Oct/2018:06:25:49 +0800  11301
#
#                                               requests
# 59   GET /dataset/315070700h-000015/resource/8955fe...
# 97   GET /dataset/a09000000e-000240/resource/514870...
# 104  GET /dataset/379730000a-001433/resource/469aa7...
# 107  GET /dataset/insight_classifiction_dataset_7_1...
# 113  GET /dataset/insight_classifiction_dataset_7_1...

# %%
org_count = pd.DataFrame({'count' : organization_data.groupby(['org']).size()}).reset_index().sort_values('count', ascending=False)
org_count
# Out:
#                                 org  count
# 11                       ipgod-nchc  53462
# 1                   data-tainan-gov  14745
# 12                         kcg-data  13440
# 4               environment-quality  13017
# 6                    github-archive   7724
# 18                  nchc-clean-data   6937
# 0                              aidm   3703
# 15                  nantou-opendata   3506
# 8                     hccg-opendata   3252
# 7                           gov-wra   2464
# 25  uci_machine_learning_repository   2415
# 22                  penghu-opendata   2163
# 17                      nchc-ai-bus   1945
# 9                         i-scipark   1617
# 2                        datamarket   1158
# 13                 most-acad-upload   1007
# 24                        tcia_data    802
# 23                       postoffice    735
# 10   information-security-open-data    535
# 16                        narl-nspo    277
# 20                             noaa    223
# 19                  nchc_restricted    201
# 3                               dot    149
# 21                    openstreetmap     44
# 14                       most-iucrp     28
# 5                          gistwdev      2

# %%
plt.pie(org_count['count'], labels = org_count['org'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()

# %%
all_org_count = pd.DataFrame({'count' : organization_data.groupby(['org']).size()}).reset_index().sort_values('count', ascending=False)
all_org_count
# Out:
#                                 org  count
# 11                       ipgod-nchc  42186
# 1                   data-tainan-gov  12702
# 12                         kcg-data  10305
# 4               environment-quality   9036
# 6                    github-archive   7180
# 0                              aidm   3279
# 15                  nantou-opendata   2766
# 7                           gov-wra   2616
# 8                     hccg-opendata   2460
# 25  uci_machine_learning_repository   2459
# 17                      nchc-ai-bus   1878
# 22                  penghu-opendata   1428
# 9                         i-scipark   1132
# 2                        datamarket   1018
# 13                 most-acad-upload    808
# 24                        tcia_data    611
# 23                       postoffice    450
# 19                  nchc_restricted    351
# 16                        narl-nspo    281
# 18                  nchc-clean-data    252
# 20                             noaa    160
# 3                               dot    116
# 21                    openstreetmap     40
# 10   information-security-open-data     29
# 5                          gistwdev     20
# 14                       most-iucrp     18

# %% [markdown]
# # 有被 Download 的前十大 org

# %%
download_org = organization_data[organization_data['download'] == True]
download_org.head()
# Out:
#                org               ip                               dataset  \
# 42   hccg-opendata  114.137.146.113  abc335a7-1c27-49cc-b153-2fe023a41afe
# 743        gov-wra     66.249.71.13  910df3d1-8162-4f67-97f8-88fc89826681
# 768       kcg-data     66.249.71.13  8f1b8a42-6c49-47fe-a341-5b792ba7a6d7
# 778     ipgod-nchc     66.249.71.13  8dad97de-6d93-49f9-92ba-3f45169a2859
# 806     ipgod-nchc     111.241.32.5  70bcf2cf-1ae6-4262-995f-e47a9e3127ce
#
#      download                                           requests
# 42       True  GET /dataset/traffic-20150128-103132-7393/reso...
# 743      True  GET /dataset/groundwaterwaterlevelobservationw...
# 768      True  GET /dataset/107-20/resource/749ba0a8-caad-471...
# 778      True  GET /dataset/376420000a-1511242101/resource/b5...
# 806      True  GET /dataset/380320000a-000095/resource/7a03a7...

# %%
org_count2 = pd.DataFrame({'count' : download_org.groupby(['org']).size()}).reset_index().sort_values('count', ascending=False).head(10)
org_count2
# Out:
#                                 org  count
# 4               environment-quality   1596
# 0                              aidm   1368
# 9                        ipgod-nchc   1216
# 10                         kcg-data    902
# 22  uci_machine_learning_repository    433
# 2                        datamarket    376
# 1                   data-tainan-gov    313
# 7                         i-scipark    276
# 14                      nchc-ai-bus    249
# 12                  nantou-opendata    245

# %%
plt.pie(org_count2['count'], labels = org_count2['org'], autopct = '%1.1f%%')
plt.axis('equal')
plt.show()
